# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv("Pharmacies.csv")
# Out:
# C:\Users\haide\AppData\Local\Temp\ipykernel_67372\610650763.py:1: DtypeWarning: Columns (33,34,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv("Pharmacies.csv")

# %%
df.head()
# Out:
#     FID        ID      SECCLASS                                        NAME  \
# 0  1001  11699187  UNCLASSIFIED                      MOWRY MEDICAL PHARMACY
# 1  1002  11699219  UNCLASSIFIED                        MOWRY PLAZA PHARMACY
# 2  1003  11698012  UNCLASSIFIED  KAISER PERMANENTE DALY CITY MEDICAL OFFICE
# 3  1004  11697767  UNCLASSIFIED      KAISER PERMANENTE TRACY MEDICAL OFFICE
# 4  1005  11666870  UNCLASSIFIED                           WALGREENS - 13596
#
#       TELEPHONE                    ADDRESS     ADDRESS2       CITY STATE  \
# 0  510-793-5011          1999 MOWRY AVENUE     SUITE 2A    FREMONT    CA
# 1  510-745-9900           668 MOWRY AVENUE                 FREMONT    CA
# 2  650-301-5788       395 HICKEY BOULEVARD  FIRST FLOOR  DALY CITY    CA
# 3  209-839-6212  2185 WEST GRANT LINE ROAD                   TRACY    CA
# 4  650-326-3404      300 UNIVERSITY AVENUE               PALO ALTO    CA
#
# ...

# %%
df.describe()
# Out:
#                 FID            ID           ZIP          FIPS  NAICSCODE  \
# count  62973.000000  6.297300e+04  62973.000000  62973.000000    62973.0
# mean   31487.367523  1.167637e+07  48078.544392  28752.158655   446110.0
# std    18179.286208  2.022253e+04  29077.538986  16541.566608        0.0
# min        1.000000  1.164063e+07    601.000000   1001.000000   446110.0
# 25%    15744.000000  1.165935e+07  25302.000000  13071.000000   446110.0
# 50%    31487.000000  1.167616e+07  44140.000000  29021.000000   446110.0
# 75%    47231.000000  1.169351e+07  75103.000000  42017.000000   446110.0
# max    62974.000000  1.171228e+07  99929.000000  78030.000000   446110.0
#
#                   X             Y
# count  62973.000000  62973.000000
# mean     -90.085441     37.192078
# std       16.488277      5.733398
# min     -170.685707    -14.290313
# 25%      -96.765715     33.749087
# 50%      -85.597432     38.365929
# 75%      -79.443438     41.137626
# ...

# %%
df.isnull().sum()
# Out:
# FID           0
# ID            0
# SECCLASS      0
# NAME          0
# TELEPHONE     0
#              ..
# PROVID_100    0
# PROVID_101    0
# HEALTH_103    0
# PROVID_104    0
# PROVID_105    0
# Length: 93, dtype: int64

# %%
catogorical_coloumn = df['ID'].head(20)

# %%
unique_counts = catogorical_coloumn.value_counts().head(20)

# %%
unique_counts
# Out:
# ID
# 11699187    1
# 11658787    1
# 11690154    1
# 11703018    1
# 11657863    1
#            ..
# 11662481    1
# 11651159    1
# 11648457    1
# 11694633    1
# 11688404    1
# Name: count, Length: 62973, dtype: int64

# %%
plt.figure(figsize=(10,6))
df['ID'].hist(bins=30,alpha=0.7,color='blue')
plt.title("Histogram of ID")
plt.xlabel('ID')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12,8))
unique_counts.plot(kind='bar',color='skyblue',alpha=0.7)
plt.title(f" Frequnacy of categaries in {catogorical_coloumn} Column")
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.show()

# %%
x=df['ID']
y=df['FID']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('Pharmacies.csv')

x_column = df['ID']  
y_column = df['FID']  


sample_size = 1000 
df_sampled = df.sample(n=sample_size, random_state=1)


plt.figure(figsize=(10, 8))
sns.scatterplot(data=df_sampled, x='ID', y='FID')


plt.title(f"Scatter Plot of FID vs ID (Sampled)")
plt.xlabel('ID')
plt.ylabel('FID')


plt.show()
# Out:
# C:\Users\haide\AppData\Local\Temp\ipykernel_67372\2973742698.py:6: DtypeWarning: Columns (33,34,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Pharmacies.csv')
